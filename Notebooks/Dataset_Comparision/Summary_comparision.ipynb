# %% [markdown]
# # Comparing Summaries/Description across CVE Mitre, NVD and CVE Details

# %% [markdown]
# ## Introduction

# %% [markdown]
# In the 3 data sources: CVE Mitre, NVD and CVE Details, we have a summary or description field that talks about the vulnerability and its attributes. This holds neccesary information for further analysis.
# In this notebook we are trying to analyse the difference in words between set pairs of data sources. This will help us identify how the description/summary gentrifies as it processes through each source

# %%
#imports
import pandas as pd
import csv
import numpy as np
from xml.etree.ElementTree import ElementTree 
import csv
import re
import glob

# %%
#read all csv files
cve_details_file = pd.read_csv("cve_details.csv")
cve_details_description = cve_details_file['description']
#print(cve_details_description)
nvd_file = pd.read_csv("nvd.csv",error_bad_lines=False)
nvd_description = nvd_file['Summary']
#print(nvd_description)

# %%
#read xml files
cve_mitre_description=[]
CVE_tree = ElementTree()
CVE_tree.parse("cve_mitre.xml")
CVE_root= CVE_tree.getroot()
cell=0
for entry in CVE_root:       
    for child in entry:
        #print (child.tag)
        if (child.tag == '{http://www.icasi.org/CVRF/schema/vuln/1.1}Notes'):
            for note in child:
                if note.attrib['Type'] =="Description":
                    cve_mitre_description.append(note.text); 
           
                    cell+=1

# %%
#converting lists into sets
nvd_description = set(nvd_description)
cve_details_description = set(cve_details_description)
cve_mitre_description = set(cve_mitre_description)

# %%
#performing the text comparision for cve mitre and nvd
nvd_added = (nvd_description -  cve_mitre_description)
nvd_removed =  (cve_mitre_description - nvd_description)
nvd_added_count = len(nvd_added)
print (nvd_added_count)
nvd_removed_count = len(nvd_removed)
print (nvd_removed_count)
# Out:
# 71738
# 84057

# %%
#performing the text comparision for nvd X cve details
details_added = (cve_details_description -  nvd_description)
details_removed =  (nvd_description - cve_details_description)
details_added_count = len(details_added)
print (details_added_count)
details_removed_count = len(details_removed)
print (details_removed_count)
# Out:
# 43654
# 47094

# %%
#performing the text comparision for cve mitre X cve details
mitre_added = (cve_mitre_description -  cve_details_description)
mitre_removed =  (cve_details_description - cve_mitre_description)
mitre_added_count = len(nvd_added)
print (mitre_added_count)
mitre_removed_count = len(mitre_removed)
print (mitre_removed_count)
# Out:
# 71738
# 68298

# %%
#creating histograms for visualization
mitre_nvd_data = {}
mitre_nvd_data["mitre_added_count"] = 71738
mitre_nvd_data["mitre_removed_count"] = 68298
mitre_details_data = {}
mitre_details_data["details_added_count"] = 43654
mitre_details_data["details_removed_count"] = 47094
details_nvd_data = {}
details_nvd_data["nvd_added_count"] = 71738
details_nvd_data["nvd_removed_count"] = 84057

# %% [markdown]
# ## Visualizations

# %%
#imports for histogram
import numpy as np
import pandas as pd
from bokeh.plotting import figure, show
from bokeh.models import Range1d
from bokeh.io import output_notebook
from bokeh.charts import Bar
import matplotlib.pyplot as plot
from datetime import datetime
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ac751d5a-454c-41d6-bb12-a50310fd8948">Loading BokehJS ...</span>
#     </div>

# %%
#creating a histogram for mitre X nvd comparision
data = {}
data['Entries'] = mitre_nvd_data
#saving in dictionary for sorting and visualising
df_data = pd.DataFrame(data).sort_values(by='Entries', ascending=True)
series = df_data.loc[:,'Entries']

p = figure(width=800, y_range=series.index.tolist(), title="Histogram of word count difference between CVE Mitre and NVD summaries")

p.xaxis.axis_label = 'Difference in word count'
p.xaxis.axis_label_text_font_size = '10pt'
p.xaxis.major_label_text_font_size = '9pt'

p.yaxis.axis_label = 'Difference in word count in CVE Mitre as compared to NVD'
p.yaxis.axis_label_text_font_size = '10pt'
p.yaxis.major_label_text_font_size = '9pt'

j = 1
for k,v in series.iteritems():
  
  #Print fields, values, orders
  #print (k,v,j) 
  p.rect(x=v/2, y=j, width=abs(v), height=0.4,
    width_units="data", height_units="data")
  j += 1
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2
type":"CategoricalTicker"},{"attributes":{"dimension":1,"plot":{"id":"6bdb64fb-fd9f-42d9-b9e1-7753eb608ab1","subtype":"Figure","type":"Plot"},"ticker":{"id":"84ce1913-da55-442a-9b38-d8ccad0fd1cb","type":"CategoricalTicker"}},"id":"f071602f-e1c8-4c91-a067-ec45dce6bf32","type":"Grid"},{"attributes":{"fill_color":{"value":"#1f77b4"},"height":{"units":"data","value":0.4},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":68298},"x":{"value":34149.0},"y":{"value":1}},"id":"b32c152a-1644-4057-a105-2c04a884f027","type":"Rect"},{"attributes":{"plot":{"id":"6bdb64fb-fd9f-42d9-b9e1-7753eb608ab1","subtype":"Figure","type":"Plot"}},"id":"14169778-e433-4f8d-93d9-198a229115c6","type":"PanTool"},{"attributes":{},"id":"d18d42b2-d046-4b3a-b3f7-233b2a86afcc","type":"BasicTicker"},{"attributes":{"plot":{"id":"6bdb64fb-fd9f-42d9-b9e1-7753eb608a ...

# %%
#creating a histogram for mitre X details comparision
data = {}
data['Entries'] = mitre_details_data
#saving in dictionary for sorting and visualising
df_data = pd.DataFrame(data).sort_values(by='Entries', ascending=True)
series = df_data.loc[:,'Entries']

p = figure(width=800, y_range=series.index.tolist(), title="Histogram of word count difference between CVE Mitre and CVE Details summaries")

p.xaxis.axis_label = 'Difference in word count'
p.xaxis.axis_label_text_font_size = '10pt'
p.xaxis.major_label_text_font_size = '9pt'

p.yaxis.axis_label = 'Difference in word count in CVE Mitre as compared to CVE Details'
p.yaxis.axis_label_text_font_size = '10pt'
p.yaxis.major_label_text_font_size = '9pt'

j = 1
for k,v in series.iteritems():
  
  #Print fields, values, orders
  #print (k,v,j) 
  p.rect(x=v/2, y=j, width=abs(v), height=0.4,
    width_units="data", height_units="data")
  j += 1
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="70c9a4b9-ec95-47b1-878a-7e17db369f85"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("70c9a4b9-ec95-47b1-878a-7e17db369f85").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("70c9a4b9-ec95-47b1-878a-7e17db369f85");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '70c9a4b9-ec95-47b1-878a-7e17db369f85' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4b9351e7-32da-4526-9b52-badbeb7c0804":{"roots":{"references":[{"attributes":{"data_source":{"id":"2d030430-963b-4c74-aa49-e59e24f084e7","type":"ColumnDataSource"},"glyph":{"id":"ea20fc24-451e-4d89-8a11-026324ce9392","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":"e1720dab-89e6-4443-9aee-5fd7567e38b7","type":"Rect"},"selection_glyph":null},"id":"83455aa5-dcdf-4648-9ad5-9dd38b68cabb","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"data","value":0.4},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":47094},"x":{"value":23547.0},"y":{"value":2}},"id":"e1720dab-89e6-4443-9aee-5fd7567e38b7","type":"Rect"},{"attributes":{"plot":null,"text":"Histogram of word count difference between CVE Mitre and CVE Details summaries"},"id":"721e8928-534a-4cf8-ab67-f8417caf357a","type":"Title"},{"attributes":{"callback":null},"id":"f63ea7bb-7787-4e8c-a5b4-4d2b676ab051","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"05362baf-b93f-46f9-90a3-de929a9a7959","type":"PanTool"},{"id":"917ccce0-048a-4d3a-ae66-adb1a9318110","type":"WheelZoomTool"},{"id":"1310dee6-5eb1-4095-8f88-4a2ffae0c54a","type":"BoxZoomTool"},{"id":"fc78e025-1753-4224-80af-7daa1db96d5d","type":"SaveTool"},{"id":"15ee2fc0-b846-40c4-97c0-edb00c3e5883","type":"ResetTool"},{"id":"d2a848b2-6c1e-4a9c-9284-f3bf3f2ce958","type":"HelpTool"}]},"id":"bcaf0c53-1e64-40b0-bc04-c0a030b46e1d","type":"Toolbar"},{"attributes":{},"id":"c0a5a3d5-8919-4c2d-947d-1b7661db2f8c","type":"ToolEvents"},{"attributes":{"callback":null},"id":"be3d1363-9878-435e-a76b-3ad00763d42b","type":"ColumnDataSource"},{"attributes":{"axis_label":"Difference in word count","formatter":{"id":"b5ab6034-fd8b-49ea-b2ac-1b9824699a55","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"9pt"},"plot":{"id":"07d178ae-b2ba-4a08-b415-01d37fa90e17","subtype":"Figure","type":"Plot"},"ticker":{"id":"e3356257-0e65-429f-b4bd-7c6756923b31","type":"BasicTicker"}},"id":"882149f3-bd88-460a-ae50-64b93023acb1","type":"LinearAxis"},{"attributes":{"callback":null,"factors":["details_added_count","details_removed_count"]},"id":"d3abc0c0-2c12-4aa5-b43d-9561e5189f68","type":"FactorRange"},{"attributes":{},"id":"e3356257-0e65-429f-b4bd-7c6756923b31","type":"BasicTicker"},{"attributes":{"plot":{"id":"07d178ae-b2ba-4a08-b415-01d37fa90e17","subtype":"Figure","type":"Plot"},"ticker":{"id":"e3356257-0e65-429f-b4bd-7c6756923b31","type":"BasicTicker"}},"id":"b68f7fdb-7224-4cec-bea9-d01155a11f1c","type":"Grid"},{"attributes":{"axis_label":"Difference in word count in CVE Mitre as compared to CVE Details","formatter":{"id":"e5f7fb70-0880-4762-9200-56ff86d0433d","type":"CategoricalTickFormatter"},"major_label_text_font_size":{"value":"9pt"},"plot":{"id":"07d178ae-b2ba-4a08-b415-01d37fa90e17","subtype":"Figure","type":"Plot"},"ticker":{"id":"07aff6ba-2627-4e31-b540-0002794ddf9f","type":"CategoricalTicker"}},"id":"7e4acb69-9f79-4b42-aaa4-ecc51daec952","type":"CategoricalAxis"},{"attributes":{},"id":"07aff6ba-2627-4e31-b540-0002794ddf9f","type":"CategoricalTicker"},{"attributes":{"dimension":1,"plot":{"id":"07d178ae-b2ba-4a08-b415-01d37fa90e17","subtype":"Figure","type":"Plot"},"ticker":{"id":"07aff6ba-2627-4e31-b540-0002794ddf9f","type":"CategoricalTicker"}},"id":"ccb891ff-e9f5-49ee-b5e5-04d740cf49ea","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b90ed67d-f7c6-479a-9b8d-024cf8b2fd43","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"07d178ae-b2ba-4a08-b415-01d37fa90e17","subtype":"Figure","type":"Plot"}},"id":"05362baf-b93f-46f9-90a3-de929a9a ...

# %%
#creating a histogram for details X nvd comparision
data = {}
data['Entries'] = details_nvd_data
#saving in dictionary for sorting and visualising
df_data = pd.DataFrame(data).sort_values(by='Entries', ascending=True)
series = df_data.loc[:,'Entries']

p = figure(width=800, y_range=series.index.tolist(), title="Histogram of word count difference between CVE Details and NVD summaries")

p.xaxis.axis_label = 'Difference in word count'
p.xaxis.axis_label_text_font_size = '10pt'
p.xaxis.major_label_text_font_size = '9pt'

p.yaxis.axis_label = 'Difference in word count in CVE Details as compared to NVD'
p.yaxis.axis_label_text_font_size = '10pt'
p.yaxis.major_label_text_font_size = '9pt'

j = 1
for k,v in series.iteritems():
  
  #Print fields, values, orders
  #print (k,v,j) 
  p.rect(x=v/2, y=j, width=abs(v), height=0.4,
    width_units="data", height_units="data")
  j += 1
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="690a8c89-4bbe-4e55-a30b-36de02be9b80"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("690a8c89-4bbe-4e55-a30b-36de02be9b80").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("690a8c89-4bbe-4e55-a30b-36de02be9b80");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '690a8c89-4bbe-4e55-a30b-36de02be9b80' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1b5dbc59-cd1f-4f08-81b1-78d70bd472b8":{"roots":{"references":[{"attributes":{},"id":"d89334dc-85df-4087-bead-bff66fd9a556","type":"CategoricalTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f6214dc8-3d23-45bd-9518-4c9f9e8e2401","type":"PanTool"},{"id":"17f81f1d-1ce3-4f98-b233-984e1de67344","type":"WheelZoomTool"},{"id":"f85088da-1f9d-4d96-a479-617ba8df2caf","type":"BoxZoomTool"},{"id":"9e23dbc3-69ec-4adb-aa24-18c85a51765e","type":"SaveTool"},{"id":"24478027-19a8-4244-9f66-6f491a13bf85","type":"ResetTool"},{"id":"2bd595ee-3a97-4539-8cc1-f0ac4272ebcc","type":"HelpTool"}]},"id":"d3b7ec64-0dc6-49bd-bb73-d919e060a3ea","type":"Toolbar"},{"attributes":{"below":[{"id":"3b870a19-ab92-4014-8ac6-2f684566ffa0","type":"LinearAxis"}],"left":[{"id":"afcffb28-ccb