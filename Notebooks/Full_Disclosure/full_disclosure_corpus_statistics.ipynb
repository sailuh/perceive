# %% [markdown]
# # Introduction
# The subject of this notebook, the [Full Disclosure (FD) mailing list](http://seclists.org/fulldisclosure/) is a "public, vendor-neutral forum for detailed discussion of vulnerabilities and exploitation techniques, as well as tools, papers, news, and events of interest to the community."
#
# Let's start our exploration by looking at the corpus of full disclosure mailing list which has been extracted and derive insights from this data.

# %% [markdown]
# # Number of Words per Document Histogram for Full Disclosure Mailing List
# We create this histogram to gain insights into the the number of words per document for a particular year as input.

# %%
#import the libraries
import pandas as pd
import glob
import os
from bokeh.charts import Histogram, output_file, show
from bokeh.io import output_notebook
import numpy as np

# %%
#Input year for which the word count histogram is being plotted
year='2012'
#Directory with the files
path = 'data/input/bodymessage_corpus/'+year

file_name_list=[]
file_wc_list=[]
file_wc_df = pd.DataFrame(columns = ["file_name","word_count"])

#function that returns the word count for all the documents in a list
def doc_wordcnt(path_file_name, file_name):
    #use open() for opening file.
    with open(path_file_name) as f:
        #create a list of all words fetched from the file using a list comprehension
        words = [word for line in f for word in line.split()]        
        #append the file name and the word count to a list
        file_name_list.append(file_name)
        file_wc_list.append(len(words))

#loop within the directory to get all the file names
for filename in os.listdir(path):
    #get the word count for every file
    doc_wordcnt(path+'/'+filename, filename)
    
#populate the column of the dataframe using the values populated in the list
file_wc_df["file_name"] = file_name_list
file_wc_df["word_count"] = file_wc_list

# %%
#Sort in ascending order of word count to split and plot multiple histograms
file_wc_asc_df = file_wc_df.sort_values("word_count", ascending=False);

# %%
#function call to display the histogram in the ipython notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9bff3519-0dd1-4a43-ad2a-ed43a1f7d86f">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Number of Words per Document Histogram
#
# In this notebook, 2012 will be used for single-year analysis.
# The histogram below shows the Number of Words per Document for '2012'. The histogram has been split into three parts to get a better picture of the number of words.
#
# To achieve this, the dataframe is split into three equal parts and the histogram is plotted for each of the subset.

# %%
#function to plot multiple histograms
def plot_hist(plot_index, plot_df, plot_year):
    #plot the histogram based on values in the dataframe
    p = 'fig'+str(plot_index)
    range_max=plot_df["word_count"].iloc[0]
    range_min=plot_df["word_count"].iloc[-1]
    p = Histogram(plot_df, values='word_count',title="Word Frequency across Documents in "+plot_year+"; Range: "+str(range_min)+" to "+str(range_max))
    
    p.xaxis.axis_label = 'Word Frequency per Document'
    p.xaxis.axis_label_text_font_size = '10pt'
    p.xaxis.major_label_text_font_size = '10pt'

    p.yaxis.axis_label = 'Frequency'
    p.yaxis.axis_label_text_font_size = '10pt'
    p.yaxis.major_label_text_font_size = '10pt'
    
    show(p)

#split the sorted dataframe into 3 and call the histogram function for each dataframe
for idx,val in enumerate(np.array_split(file_wc_asc_df, 3)):
    #Get the year from the filename for the first record
    year=file_wc_asc_df.file_name[0][:4]
    plot_hist(idx, val, year)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b4510b6e-59c2-4554-a863-8e5ff9b10caf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("b4510b6e-59c2-4554-a863-8e5ff9b10caf").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b4510b6e-59c2-4554-a863-8e5ff9b10caf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b4510b6e-59c2-4554-a863-8e5ff9b10caf' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4e81d411-6d13-4b90-ad79-d0347c7274e8":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(5167.188976, 5229.425197]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(5167.188976, 5229.425197]"],"line_alpha":[1.0],"line_color":["black"],"width":[62.236220472441346],"x":["5198.3070865"],"y":[0.0]}},"id":"dcc2e086-f559-4c59-9971-510de1f33c2a","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"458f4564-6087-42ba-b282-44b0bd26c97b","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(7843.346457, 7905.582677]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(7843.346457, 7905.582677]"],"line_alpha":[1.0],"line_color":["black"],"width":[62.236220472440436],"x":["7874.464567"],"y":[0.0]}},"id":"c8af13cb-c263-4b4f-bebf-4666a2a08422","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9f93226a-2a43-4ec9-9140-28bde1622c00","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(2615.503937, 2677.740157]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":["(2615.503937, 2677.740157]"],"line_alpha":[1.0],"line_color":["black"],"width":[62.236220472441346],"x":["2646.622047"],"y":[0.5]}},"id":"e47c9969-7566-40b4-a77a-1b1c4500f725","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"091f9c98-b158-442a-a118-9cbdc233b390","type":"Rect"},{"attributes":{"data_source":{"id":"53c3962f-bb28-4db4-86fa-473fb4cf1b63","type":"ColumnDataSource"},"glyph":{"id":"655f02c7-7ab8-41e8-9e72-f1b12881488a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"82a13f53-4dce-4ec9-b593-a3a9639db8e1","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(3113.393701, 3175.629921]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":["(3113.393701, 3175.629921]"],"line_alpha":[1.0],"line_color":["black"],"width":[62.23622047244089],"x":["3144.511811"],"y":[0.5]}},"id":"f31f35d3-8706-4756-8489-9d898f47b5f8","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9696ae6e-5b33-4407-8e7d-175307295a30","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0d930e0c-c1fc-4805-b881-f31c715bdb3d","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(3362.338583, 3424.574803]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(3362.338583, 3424.574803]"],"line_alpha":[1.0],"line_color":["black"],"wid ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3ef62bb1-bd10-4bf1-859b-8b563c77b2ab"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("3ef62bb1-bd10-4bf1-859b-8b563c77b2ab").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3ef62bb1-bd10-4bf1-859b-8b563c77b2ab");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3ef62bb1-bd10-4bf1-859b-8b563c77b2ab' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4fbd72e0-47ca-4f7d-bf04-52a1c4462c39":{"roots":{"references":[{"attributes":{"plot":{"id":"804c11b1-ad5b-49bd-aba6-f164ed732f6f","subtype":"Chart","type":"Plot"}},"id":"8c218409-3527-43f2-a185-c09f92dd4a9c","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(300.384615, 315.307692]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[99.0],"label":["(300.384615, 315.307692]"],"line_alpha":[1.0],"line_color":["black"],"width":[14.923076923076962],"x":["307.8461535"],"y":[49.5]}},"id":"da97cde1-2a63-48fb-af6b-b980c6b8a962","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"314dcd6d-9a71-47ef-98ff-bbdb79325a43","type":"Rect"},{"attributes":{"plot":null,"text":"Word Frequency across Documents in 2012; Range: 181 to 375"},"id":"ffddf047-c334-417d-aec7-6b4e25501b33","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"804c11b1-ad5b-49bd-aba6-f164ed732f6f","subtype":"Chart","type":"Plot"},"ticker":{"id":"645084a5-37a0-4734-916e-182b62587f34","type":"BasicTicker"}},"id":"6bae1cc0-b9da-4d30-84f5-5e45f0cc6ba1","type":"Grid"},{"attributes":{},"id":"27706a80-125c-42c7-84e0-57fd9c6ba386","type":"ToolEvents"},{"attributes":{"data_source":{"id":"31a2b644-fc04-47d4-91f4-f28aaf7826c3","type":"ColumnDataSource"},"glyph":{"id":"64d78f04-f8c6-4a77-83a4-ec47e745bff3","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"7b0cdbb1-c7a7-4778-a4c7-2efe39a725f0","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(345.153846, 360.076923]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[73.0],"label":["(345.153846, 360.076923]"],"line_alpha":[1.0],"line_color":["black"],"width":[14.923076923076906],"x":["352.6153845"],"y":[36.5]}},"id":"31a2b644-fc04-47d4-91f4-f28aaf7826c3","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"b15d07e9-0e34-4c08-ad17-7fdeba8540d7","type":"ColumnDataSource"},"glyph":{"id":"a111c301-3692-4208-afc3-868a0e1e8a87","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ceaad332-b2ec-4865-87e6-d9fce6e65c47","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(210.846154, 225.769231]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[133.0],"label":["(210.846154, 225.769231]"],"line_alpha":[1.0],"line_color":["black"],"width":[14.923076923076934],"x":["218.3076925"],"y":[66.5]}},"id":"64a46f56-29b3-48f5-a9ec-4bca4ad3bf4b","type":"ColumnDataSource"},{"attributes":{},"id":"716f501a-ddb5-4254-b08f-da1db499daf9","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"872d6e63-4f3b-4d4e-be10-b51a73903bd0","type":"Rect"},{"attributes":{"data_source":{"id":"97c6e43c-419e-483b-8e10-311a0c75b7d0","type":"ColumnDataSource"},"glyph":{"id":"872d6e63-4f3b-4d4e-be10-b51a73903bd0","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"13080803-8421-4e49-a1c6-a0f5faac4b21","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(195.923077, 210.846154]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[135.0],"label":["(195.923077, 210.846154]"],"line_alpha":[1.0],"line_color":["black" ...
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f65eac2e-2b3d-4094-991f-8561987d096b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("f65eac2e-2b3d-4094-991f-8561987d096b").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f65eac2e-2b3d-4094-991f-8561987d096b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f65eac2e-2b3d-4094-991f-8561987d096b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8faf852b-9447-469d-a70a-e5d0b3e712fc":{"roots":{"references":[{"attributes":{"callback":null,"end":185.925,"start":11.075},"id":"ee934f80-124c-4308-a48a-c470bf55b01b","type":"Range1d"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(98.500000, 112.250000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[128.0],"label":["(98.500000, 112.250000]"],"line_alpha":[1.0],"line_color":["black"],"width":[13.75],"x":["105.375"],"y":[64.0]}},"id":"52be71a2-282e-4e74-9046-ee1f7606272e","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"0b91c608-41c4-4962-8ec5-4cb3cf11f1ff","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"83314741-d631-4eac-8abc-4a81804e36c7","type":"LinearAxis"}],"renderers":[{"id":"8c140460-ac9c-44f3-8f5c-e5a1a7c89f74","type":"BoxAnnotation"},{"id":"7098f1b4-7671-4149-bb08-4ea293c374b0","type":"GlyphRenderer"},{"id":"8785d98f-15ac-4714-be66-6903cb2dfcb3","type":"GlyphRenderer"},{"id":"647fa31f-dc86-41f9-abfd-82dabf3008bd","type":"GlyphRenderer"},{"id":"ec7409b8-abec-43a5-b0c5-c8812f162cb1","type":"GlyphRenderer"},{"id":"a1d0fb05-a795-416e-bea3-fdd3a135b6c1","type":"GlyphRenderer"},{"id":"b672bc24-697f-4946-8ca0-fae73928b0b2","type":"GlyphRenderer"},{"id":"eee135e3-c3e3-4b20-a32f-b628120616ee","type":"GlyphRenderer"},{"id":"7e7a460b-779b-4fc0-aa9f-2e9e3728ecc0","type":"GlyphRenderer"},{"id":"f894091f-245c-445b-99a7-6f22f2cec4e0","type":"GlyphRenderer"},{"id":"d083c660-69eb-43d8-a4b0-a5a1723b5f99","type":"GlyphRenderer"},{"id":"0ac8c0f4-0b77-4b88-9069-d7bbc921cc02","type":"GlyphRenderer"},{"id":"8dda6aca-2aa7-498e-a782-88569279e729","type":"GlyphRenderer"},{"id":"a6d1e89d-ed7d-4c9d-9c0a-4f079885e5f3","type":"Legend"},{"id":"0b91c608-41c4-4962-8ec5-4cb3cf11f1ff","type":"LinearAxis"},{"id":"83314741-d631-4eac-8abc-4a81804e36c7","type":"LinearAxis"},{"id":"bcf3abb0-c7f2-4200-bbcd-783b6b8f0c57","type":"Grid"}],"title":{"id":"b3739218-446f-4fd0-bfd8-4343b669378d","type":"Title"},"tool_events":{"id":"07fb0fd4-1725-4a6e-a783-c5313a4cecf8","type":"ToolEvents"},"toolbar":{"id":"dd7b34ec-281b-4a5a-93b9-6dbc105e8a02","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"ee934f80-124c-4308-a48a-c470bf55b01b","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"352ee73a-dd74-4c8c-8085-eef5662bd222","type":"Range1d"}},"id":"d9132b2b-6d27-410f-8c48-26e4f4bc83ee","subtype":"Chart","type":"Plot"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9fe03d01-a597-4662-aae2-dcec80b27f69","type":"Rect"},{"attributes":{"data_source":{"id":"41feefec-f514-4c45-97d6-61f2b6d76843","type":"ColumnDataSource"},"glyph":{"id":"8c736047-b2f9-48d0-afdc-8f63c68f4ba2","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8dda6aca-2aa7-498e-a782-88569279e729","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(57.250000, 71.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[102.0],"label":["(57.250000, 71.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[13.75],"x":["64.125"],"y":[51.0]}},"id":"bc3175c7-902a-4119-9aa0-a789762b10eb","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"bc3175c7-902a-4119-9aa0-a789762b10eb","type":"ColumnDataSource"},"glyph":{"id":"8bcbe104-5884-40b2-91f1-d5300bc22f38","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ec7409b8-abec-43a5-b0c5-c8812f162cb1","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"0c95fc24-0f4c-4df8-b171-111442b7bad6","type":"ColumnDataSource"},"glyph":{"id":"2b56c483-42ef-4f64-a7bd-48a9b3164d1f","type":"Rect"},"hover_glyp ...

# %%
print "File name :", file_wc_df.file_name[file_wc_df['word_count'].idxmax()], ", Maximum (word count) :", file_wc_df.word_count[file_wc_df['word_count'].idxmax()]
print "File name :", file_wc_df.file_name[file_wc_df['word_count'].idxmin()], ", Minimum (word count) :", file_wc_df.word_count[file_wc_df['word_count'].idxmin()]
# Out:
# File name : 2012_Mar_341.txt , Maximum (word count) : 8279
# File name : 2012_Apr_241.txt , Minimum (word count) : 16
